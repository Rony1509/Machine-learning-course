# %%
import pandas as pd
import numpy as np

# %%
data = [10, 20, 30, 40]

series = pd.Series(data)

print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={
    'name':['Rony','Rakib','Rubel','Sakib','Einstein','Newton','Bhor'],
    'age':[23,22,26,27,28,56,44],
    'city':['Dhak','Rajshahi','Khulna','Barishal','Bogura','London','New York']
}
df2=pd.DataFrame(data)
print(df2)
# Out:
#        name  age      city
# 0      Rony   23      Dhak
# 1     Rakib   22  Rajshahi
# 2     Rubel   26    Khulna
# 3     Sakib   27  Barishal
# 4  Einstein   28    Bogura
# 5    Newton   56    London
# 6      Bhor   44  New York

# %%
print(df2.head())
# Out:
#        name  age      city
# 0      Rony   23      Dhak
# 1     Rakib   22  Rajshahi
# 2     Rubel   26    Khulna
# 3     Sakib   27  Barishal
# 4  Einstein   28    Bogura

# %%
print(df2.tail(3))
# Out:
#        name  age      city
# 4  Einstein   28    Bogura
# 5    Newton   56    London
# 6      Bhor   44  New York

# %%
print(df2.shape)
# Out:
# (7, 3)

# %%
print(df2.columns)
# Out:
# Index(['name', 'age', 'city'], dtype='str')

# %%
print(df2.describe())
# Out:
#              age
# count   7.000000
# mean   32.285714
# std    12.763415
# min    22.000000
# 25%    24.500000
# 50%    27.000000
# 75%    36.000000
# max    56.000000

# %%
print(df2["age"])
# Out:
# 0    23
# 1    22
# 2    26
# 3    27
# 4    28
# 5    56
# 6    44
# Name: age, dtype: int64

# %%
print(df2[["name", "city"]])
# Out:
#        name      city
# 0      Rony      Dhak
# 1     Rakib  Rajshahi
# 2     Rubel    Khulna
# 3     Sakib  Barishal
# 4  Einstein    Bogura
# 5    Newton    London
# 6      Bhor  New York

# %%
print(df2.dtypes)
# Out:
# name      str
# age     int64
# city      str
# dtype: object
