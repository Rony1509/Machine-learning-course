# %%
import pandas as pd
import numpy as np

# %%
data = [10, 20, 30, 40]

series = pd.Series(data)

print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={
    'name':['Rony','Rakib','Rubel','Sakib','Einstein','Newton','Bhor','Rohan','Abul'],
    'age':[23,22,26,27,28,56,44,32,43],
    'city':['Dhaka','Rajshahi','Khulna','Barishal','Bogura','London','New York','Dhaka','Dhaka']
}
df2=pd.DataFrame(data)
print(df2)
# Out:
#        name  age      city
# 0      Rony   23     Dhaka
# 1     Rakib   22  Rajshahi
# 2     Rubel   26    Khulna
# 3     Sakib   27  Barishal
# 4  Einstein   28    Bogura
# 5    Newton   56    London
# 6      Bhor   44  New York
# 7     Rohan   32     Dhaka
# 8      Abul   43     Dhaka

# %%
print(df2.head())
# Out:
#        name  age      city
# 0      Rony   23     Dhaka
# 1     Rakib   22  Rajshahi
# 2     Rubel   26    Khulna
# 3     Sakib   27  Barishal
# 4  Einstein   28    Bogura

# %%
print(df2.tail(3))
# Out:
#     name  age      city
# 6   Bhor   44  New York
# 7  Rohan   32     Dhaka
# 8   Abul   43     Dhaka

# %%
print(df2.shape)
# Out:
# (9, 3)

# %%
print(df2.columns)
# Out:
# Index(['name', 'age', 'city'], dtype='str')

# %%
print(df2.describe())
# Out:
#              age
# count   9.000000
# mean   33.444444
# std    11.620145
# min    22.000000
# 25%    26.000000
# 50%    28.000000
# 75%    43.000000
# max    56.000000

# %%
print(df2["age"])
# Out:
# 0    23
# 1    22
# 2    26
# 3    27
# 4    28
# 5    56
# 6    44
# 7    32
# 8    43
# Name: age, dtype: int64

# %%
print(df2[["name", "city"]])
# Out:
#        name      city
# 0      Rony     Dhaka
# 1     Rakib  Rajshahi
# 2     Rubel    Khulna
# 3     Sakib  Barishal
# 4  Einstein    Bogura
# 5    Newton    London
# 6      Bhor  New York
# 7     Rohan     Dhaka
# 8      Abul     Dhaka

# %%
print(df2.dtypes)
# Out:
# name      str
# age     int64
# city      str
# dtype: object

# %%
#Access df["col"] or df[["col1","col2"]] df.loc[index] or df.iloc[index]

print(df2.loc[2])
# Out:
# name     Rubel
# age         26
# city    Khulna
# Name: 2, dtype: object

# %%
df2.loc[0]
# Out:
# name     Rony
# age        23
# city    Dhaka
# Name: 0, dtype: object

# %%
#df[condition]
#df.loc[row_indexer, column_indexer]

print(df2[df2["age"]>25]);
print(df2.loc[df2["age"] > 27, ["name", "city"]]
)
# Out:
#        name  age      city
# 2     Rubel   26    Khulna
# 3     Sakib   27  Barishal
# 4  Einstein   28    Bogura
# 5    Newton   56    London
# 6      Bhor   44  New York
# 7     Rohan   32     Dhaka
# 8      Abul   43     Dhaka
#        name      city
# 4  Einstein    Bogura
# 5    Newton    London
# 6      Bhor  New York
# 7     Rohan     Dhaka
# 8      Abul     Dhaka

# %%
print(df2.loc[df2["city"]=="Khulna"])
# Out:
#     name  age    city
# 2  Rubel   26  Khulna

# %%
print(df2.loc[(df2["city"]=="Dhaka") & (df2["age"]>25)])
# Out:
#     name  age   city
# 7  Rohan   32  Dhaka
# 8   Abul   43  Dhaka
